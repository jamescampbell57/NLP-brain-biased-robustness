# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from transformers import AutoTokenizer
from transformers import BertModel
from datasets import load_dataset

from torch.optim import AdamW
from transformers import get_scheduler
from tqdm.auto import tqdm

# %%
mnli = load_dataset('glue','mnli')
# Out:
# Reusing dataset glue (/home/ubuntu/.cache/huggingface/datasets/glue/mnli/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad)
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
mnli['train']
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['premise', 'hypothesis', 'label', 'idx'],
#         num_rows: 392702
#     })
#     validation_matched: Dataset({
#         features: ['premise', 'hypothesis', 'label', 'idx'],
#         num_rows: 9815
#     })
#     validation_mismatched: Dataset({
#         features: ['premise', 'hypothesis', 'label', 'idx'],
#         num_rows: 9832
#     })
#     test_matched: Dataset({
#         features: ['premise', 'hypothesis', 'label', 'idx'],
#         num_rows: 9796
#     })
#     test_mismatched: Dataset({
#         features: ['premise', 'hypothesis', 'label', 'idx'],
#         num_rows: 9847
#     })
# })

# %%
import csv
data_path = '/home/ubuntu/NLP-brain-biased-robustness/data/mnli/multinli_1.0/'
train = []
with open(data_path+'multinli_1.0_dev_mismatched.txt') as file:
    tsv_file = csv.reader(file, delimiter="\t")
    for line in tsv_file:
        #if line[9]
        train.append(line)
        
        
#5,6
#print(dev_matched[0])
#dev_matched[90]

# %% [markdown]
# # Letters and facetoface are in mismatched!

# %%
cont = 0
alli = set()
for ex in train:
    #for n in range(len(ex)):
    #    if ex[n] == 'facetoface':
    #        cont += 1
    alli.add(ex[9])
alli
# Out:
# {'facetoface', 'genre', 'letters', 'nineeleven', 'oup', 'verbatim'}

# %%
import pandas as pd
import csv
from csv import QUOTE_NONE
import random

data_path = '/home/ubuntu/NLP-brain-biased-robustness/data/mnli/multinli_1.0/'

train_loc = data_path + 'multinli_1.0_train.txt'
dev_loc = data_path + 'multinli_1.0_dev_matched.txt'
def read_table(loc):
    return pd.read_csv(loc, sep='\t', index_col=0, quoting=QUOTE_NONE)

train = read_table(train_loc)
dev = read_table(dev_loc)

# telephone - face2face/letter
header = ['index'] + list(train.columns)

def write_split(s, tag, genre):
    cnt = 0
    with open("{}.tsv".format(tag), 'w', encoding="UTF-8") as fout:
        writer = csv.writer(fout, delimiter='\t')
        writer.writerow(header)
        for i in s.itertuples():
            if i[9] == genre:
                cnt += 1
                writer.writerow(list(i))
    print(genre, cnt)

write_split(train, "train-telephone", "telephone")
write_split(dev, "dev-telephone", "telephone")
write_split(dev, "dev-letters", "letters")
write_split(dev, "dev-facetoface", "facetoface")
# Out:
# telephone 83348
# telephone 2000
# letters 0
# facetoface 0

# %%
train
# Out:
#                                           sentence1_binary_parse  \
# gold_label
# neutral        ( ( Conceptually ( cream skimming ) ) ( ( has ...
# entailment     ( you ( ( know ( during ( ( ( the season ) and...
# entailment     ( ( One ( of ( our number ) ) ) ( ( will ( ( (...
# entailment     ( ( How ( ( ( do you ) know ) ? ) ) ( ( All th...
# neutral        ( yeah ( i ( ( tell you ) ( what ( ( though ( ...
# ...                                                          ...
# contradiction  ( Clearly ( , ( California ( ( ( can ( - ( and...
# neutral        ( It ( ( ( was once ) ( regarded ( as ( ( the ...
# entailment     ( Houseboats ( ( are ( ( a ( ( beautifully pre...
# neutral        ( Obituaries ( fondly ( ( ( ( recalled ( his (...
# neutral        ( ( ( ( in ( that other ) ) ( you ( know ( uh ...
#
#                                           sentence2_binary_parse  \
# gold_label
# neutral        ( ( ( Product and ) geography ) ( ( are ( what...
# entailment     ( You ( ( ( ( lose ( the things ) ) ( to ( the...
# entailment     ( ( ( A member ) ( of ( my team ) ) ) ( ( will...
# entailment     ( ( This information ) ( ( belongs ( to them )...
# neutral        ( ( The ( tennis shoes ) ) ( ( have ( ( a rang...
# ...                                                          ...
# contradiction  ( California ( ( ( can not ) ( do ( any better...
# neutral        ( So ( ( many ( of ( the ( original buildings ...
# entailment     ( ( ( The tradition ) ( of houseboats ) ) ( ( ...
# neutral        ( ( The obituaries ) ( ( were ( ( beautiful an...
# neutral        ( ( My husband ) ( ( has ( ( been ( so overwor...
#
#                                                  sentence1_parse  \
# gold_label
# neutral        (ROOT (S (NP (JJ Conceptually) (NN cream) (NN ...
# entailment     (ROOT (S (NP (PRP you)) (VP (VBP know) (PP (IN...
# entailment     (ROOT (S (NP (NP (CD One)) (PP (IN of) (NP (PR...
# entailment     (ROOT (S (SBARQ (WHADVP (WRB How)) (SQ (VBP do...
# neutral        (ROOT (S (VP (VB yeah) (S (NP (FW i)) (VP (VB ...
# ...                                                          ...
# contradiction  (ROOT (S (ADVP (RB Clearly)) (, ,) (NP (NNP Ca...
# neutral        (ROOT (S (NP (PRP It)) (VP (VBD was) (ADVP (RB...
# entailment     (ROOT (S (NP (NNS Houseboats)) (VP (VBP are) (...
# neutral        (ROOT (S (NP (NNS Obituaries)) (ADVP (RB fondl...
# neutral        (ROOT (SBAR (SBAR (WHPP (IN in) (WHNP (WDT tha...
#
#                                                  sentence2_parse  \
# gold_label
# neutral        (ROOT (S (NP (NN Product) (CC and) (NN geograp...
# entailment     (ROOT (S (NP (PRP You)) (VP (VBP lose) (NP (DT...
# entailment     (ROOT (S (NP (NP (DT A) (NN member)) (PP (IN o...
# entailment     (ROOT (S (NP (DT This) (NN information)) (VP (...
# neutral        (ROOT (S (NP (DT The) (NN tennis) (NNS shoes))...
# ...                                                          ...
# contradiction  (ROOT (S (NP (NNP California)) (VP (MD can) (R...
# neutral        (ROOT (S (IN So) (NP (NP (JJ many)) (PP (IN of...
# entailment     (ROOT (S (NP (NP (DT The) (NN tradition)) (PP ...
# neutral        (ROOT (S (NP (DT The) (NNS obituaries)) (VP (V...
# neutral        (ROOT (S (NP (PRP$ My) (NN husband)) (VP (VBZ ...
#
#                                                        sentence1  \
# gold_label
# neutral        Conceptually cream skimming has two basic dime...
# entailment     you know during the season and i guess at at y...
# entailment     One of our number will carry out your instruct...
# entailment     How do you know? All this is their information...
# neutral        yeah i tell you what though if you go price so...
# ...                                                          ...
# contradiction    Clearly, California can - and must - do better.
# neutral        It was once regarded as the most beautiful str...
# entailment     Houseboats are a beautifully preserved traditi...
# neutral        Obituaries fondly recalled his on-air debates ...
# neutral        in that other you know uh that i should do it ...
#
#                                                        sentence2  promptID  \
# gold_label
# neutral        Product and geography are what make cream skim...     31193
# entailment     You lose the things to the following level if ...    101457
# entailment     A member of my team will execute your orders w...    134793
# entailment                     This information belongs to them.     37397
# neutral                 The tennis shoes have a range of prices.     50563
# ...                                                          ...       ...
# contradiction                   California cannot do any better.     30418
# neutral        So many of the original buildings had been rep...    105454
# entailment     The tradition of houseboats originated while t...     13960
# neutral        The obituaries were beautiful and written in k...    114061
# neutral        My husband has been so overworked lately that ...      2065
#
#                 pairID       genre         label1  label2  label3  label4  \
# gold_label
# neutral         31193n  government        neutral     NaN     NaN     NaN
# entailment     101457e   telephone     entailment     NaN     NaN     NaN
# entailment     134793e     fiction     entailment     NaN     NaN     NaN
# entailment      37397e     fiction     entailment     NaN     NaN     NaN
# neutral         50563n   telephone        neutral     NaN     NaN     NaN
# ...                ...         ...            ...     ...     ...     ...
# contradiction   30418c  government  contradiction     NaN     NaN     NaN
# neutral        105454n      travel        neutral     NaN     NaN     NaN
# entailment      13960e      travel     entailment     NaN     NaN     NaN
# neutral        114061n       slate        neutral     NaN     NaN     NaN
# neutral          2065n   telephone        neutral     NaN     NaN     NaN
#
#                label5
# gold_label
# neutral           NaN
# entailment        NaN
# entailment        NaN
# entailment        NaN
# neutral           NaN
# ...               ...
# contradiction     NaN
# neutral           NaN
# entailment        NaN
# neutral           NaN
# neutral           NaN
#
# [392702 rows x 14 columns]

# %%
dev_matched
# Out:
# [['gold_label',
#   'sentence1_binary_parse',
#   'sentence2_binary_parse',
#   'sentence1_parse',
#   'sentence2_parse',
#   'sentence1',
#   'sentence2',
#   'promptID',
#   'pairID',
#   'genre',
#   'label1',
#   'label2',
#   'label3',
#   'label4',
#   'label5'],
#  ['neutral',
#   '( ( The ( new rights ) ) ( are ( nice enough ) ) )',
#   '( Everyone ( really ( likes ( the ( newest benefits ) ) ) ) )',
#   '(ROOT (S (NP (DT The) (JJ new) (NNS rights)) (VP (VBP are) (ADJP (JJ nice) (RB enough)))))',
#   '(ROOT (S (NP (NN Everyone)) (VP (ADVP (RB really)) (VBZ likes) (NP (DT the) (JJS newest) (NNS benefits)))))',
#   'The new rights are nice enough',
#   'Everyone really likes the newest benefits ',
#   '63735',
#   '63735n',
#   'slate',
#   'neutral',
#   'entailment',
#   'neutral',
#   'neutral',
#   'neutral'],
#  ['contradiction',
#   '( ( This site ) ( ( includes ( ( ( ( a list ) ( of ( all ( award winners ) ) ) ) and ) ( ( a ( searchable database ) ) ( of ( Government ( Executive articles ) ) ) ) ) ) . ) )',
#   '( ( ( The ( Government ( Executive articles ) ) ) ( housed ( on ( the website ) ) ) ) ( ( ( are not ) ( able ( to ( be searched ) ) ) ) . ) )',
#   '(ROOT (S (NP (DT This) (NN site)) (VP (VBZ includes) (NP (NP (NP (DT a) (NN list)) (PP (IN of) (NP (DT all) (NN award) (NNS winners)))) (CC and) (NP (NP (DT a) (JJ searchable) (NN database)) (PP (IN of) (NP (NNP Government) (NNP Executive) (NNS articles)))))) (. .)))',
#   '(ROOT (S (NP (NP (DT The) (NNP Government) (NNP Executive) (NNS articles)) (VP (VBN housed) (PP (IN on) (NP (DT the) (NN website))))) (VP (VBP are) (RB not) (ADJP (JJ able) (S (VP (TO to) (VP (VB be) (ADJP (JJ searched))))))) (. .)))',
#   'This site includes a list of all award winners and a searchable database of Government Executive articles.',
#   'The Government Executive articles housed on the website are not able to be searched.',
#   '91383',
#   '91383c',
#   'government',
#   'contradiction',
#   'contradiction',
#   'contradiction',
#   'contradiction',
#   'contradiction'],
#  ['entailment',
#   "( ( ( ( uh ( i ( ( do n't ) ( know ( ( i i ) ( have ( ( mixed emotions ) ( about ( him ( ( uh sometimes ) ( i ( like him ) ) ) ) ) ) ) ) ) ) ) ) but ) ( ( at ( the ( same times ) ) ) ( i ( love ( to ( see somebody ) ) ) ) ) ) ( beat him ) )",
#   '( I ( ( ( ( ( ( like him ) ( for ( the ( most part ) ) ) ) , ) but ) ( ( would still ) ( enjoy ( seeing ( someone ( beat him ) ) ) ) ) ) . ) )',
#   "(ROOT (SINV (S (S (INTJ (UH uh)) (NP (FW i)) (VP (VBP do) (RB n't) (VP (VB know) (NP (NP (FW i) (FW i)) (SBAR (S (VP (VBP have) (VP (VBN mixed) (NP (NNS emotions)) (PP (IN about) (S (NP (PRP him)) (VP (VBG uh) (ADVP (RB sometimes)) (NP (NP (FW i)) (PP (IN like) (NP (PRP him))))))))))))))) (CC but) (S (PP (IN at) (NP (DT the) (JJ same) (NNS times))) (NP (FW i)) (VP (VBP love) (S (VP (TO to) (VP (VB see) (NP (NN somebody)))))))) (VP (VBD beat)) (NP (PRP him))))",
#   '(ROOT (S (NP (PRP I)) (VP (VP (VBP like) (NP (PRP him)) (PP (IN for) (NP (DT the) (JJS most) (NN part)))) (, ,) (CC but) (VP (MD would) (ADVP (RB still)) (VP (VB enjoy) (S (VP (VBG seeing) (S (NP (NN someone)) (VP (VB beat) (NP (PRP him))))))))) (. .)))',
#   "uh i don't know i i have mixed emotions about him uh sometimes i like him but at the same times i love to see somebody beat him",
#   'I like him for the most part, but would still enjoy seeing someone beat him.',
#   '755',
#   '755e',
#   'telephone',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment'],
#  ['contradiction',
#   "( yeah ( ( i i ) ( think ( ( my ( favorite restaurant ) ) ( ( is always ) ( been ( ( the ( one closest ) ) ( you ( ( know ( the closest ) ) ( ( as long ) ( as ( it ( 's ( it ( meets ( ( the ( minimum criteria ) ) ( you ( know ( of ( good food ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) )",
#   '( ( My ( favorite restaurants ) ) ( ( ( ( are always ) ( ( ( ( ( at least ) a ) hundred ) miles ) away ) ) ( from ( my house ) ) ) . ) )',
#   "(ROOT (S (VP (VB yeah) (NP (NP (FW i) (FW i)) (SBAR (S (VP (VBP think) (SBAR (S (NP (PRP$ my) (JJ favorite) (NN restaurant)) (VP (VBZ is) (ADVP (RB always)) (VP (VBN been) (NP (NP (DT the) (CD one) (JJS closest)) (SBAR (S (NP (PRP you)) (VP (VBP know) (NP (DT the) (JJS closest)) (ADVP (ADVP (RB as) (RB long)) (SBAR (IN as) (S (NP (PRP it)) (VP (VBZ 's) (SBAR (S (NP (PRP it)) (VP (VBZ meets) (NP (NP (DT the) (JJ minimum) (NNS criteria)) (SBAR (S (NP (PRP you)) (VP (VBP know) (PP (IN of) (NP (JJ good) (NN food)))))))))))))))))))))))))))))",
#   '(ROOT (S (NP (PRP$ My) (JJ favorite) (NNS restaurants)) (VP (VBP are) (ADVP (RB always)) (ADVP (NP (QP (IN at) (JJS least) (DT a) (CD hundred)) (NNS miles)) (RB away)) (PP (IN from) (NP (PRP$ my) (NN house)))) (. .)))',
#   "yeah i i think my favorite restaurant is always been the one closest  you know the closest as long as it's it meets the minimum criteria you know of good food",
#   'My favorite restaurants are always at least a hundred miles away from my house. ',
#   '78013',
#   '78013c',
#   'telephone',
#   'contradiction',
#   'contradiction',
#   'contradiction',
#   'contradiction',
#   'contradiction'],
#  ['contradiction',
#   "( i ( ( do n't ) ( know ( um ( do ( you ( do ( ( a lot ) ( of camping ) ) ) ) ) ) ) ) )",
#   '( I ( ( know exactly ) . ) )',
#   "(ROOT (S (NP (FW i)) (VP (VBP do) (RB n't) (VP (VB know) (SBAR (S (NP (NN um)) (VP (VBP do) (SBAR (S (NP (PRP you)) (VP (VBP do) (NP (NP (DT a) (NN lot)) (PP (IN of) (NP (NN camping))))))))))))))",
#   '(ROOT (S (NP (PRP I)) (VP (VBP know) (ADVP (RB exactly))) (. .)))',
#   "i don't know um do you do a lot of camping",
#   'I know exactly.',
#   '96377',
#   '96377c',
#   'telephone',
#   'contradiction',
#   'contradiction',
#   'contradiction',
#   'contradiction',
#   'contradiction'],
#  ['contradiction',
#   "( well ( that ( would ( be ( ( a help ) ( i ( wish ( they ( would ( do ( that ( ( ( here ( we ( have ( got ( so ( ( little ( landfill space ) ) ( left ( that ( we ( 're ( going ( to ( ( run out ) ( before ( ( the end ) ( of ( this decade ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) and ) ( it ( ( 's really ) ( going ( to be ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) )",
#   '( We ( ( have ( plenty ( of ( space ( in ( the landfill ) ) ) ) ) ) . ) )',
#   "(ROOT (FRAG (ADVP (RB well)) (SBAR (WHNP (WDT that)) (S (VP (MD would) (VP (VB be) (NP (NP (DT a) (NN help)) (SBAR (S (NP (FW i)) (VP (VBP wish) (SBAR (S (NP (PRP they)) (VP (MD would) (VP (VB do) (SBAR (IN that) (S (S (ADVP (RB here)) (NP (PRP we)) (VP (VBP have) (VP (VBN got) (SBAR (IN so) (S (NP (JJ little) (NN landfill) (NN space)) (VP (VBD left) (SBAR (IN that) (S (NP (PRP we)) (VP (VBP 're) (VP (VBG going) (S (VP (TO to) (VP (VB run) (PRT (RP out)) (PP (IN before) (NP (NP (DT the) (NN end)) (PP (IN of) (NP (DT this) (NN decade)))))))))))))))))) (CC and) (S (NP (PRP it)) (VP (VBZ 's) (ADVP (RB really)) (VP (VBG going) (S (VP (TO to) (VP (VB be)))))))))))))))))))))))",
#   '(ROOT (S (NP (PRP We)) (VP (VBP have) (NP (NP (RB plenty)) (PP (IN of) (NP (NP (NN space)) (PP (IN in) (NP (DT the) (NN landfill))))))) (. .)))',
#   "well that would be a help i wish they would do that here we have got so little landfill space left that we're going to run out before the end of this decade and it's really going to be",
#   'We have plenty of space in the landfill.',
#   '139749',
#   '139749c',
#   'telephone',
#   'contradiction',
#   'contradiction',
#   'contradiction',
#   'contradiction',
#   'contradiction'],
#  ['contradiction',
#   '( yeah ( ( ( i know ) and ) ( i ( did ( that ( ( ( all ( through college ) ) and ) ( it ( worked too ) ) ) ) ) ) ) )',
#   '( I ( ( ( did ( that all ) ) ( through college ) ) ( but ( it ( never worked ) ) ) ) )',
#   '(ROOT (S (VP (VB yeah) (S (S (NP (FW i)) (VP (VBP know))) (CC and) (S (NP (FW i)) (VP (VBD did) (SBAR (IN that) (S (S (NP (DT all)) (PP (IN through) (NP (NN college)))) (CC and) (S (NP (PRP it)) (VP (VBD worked) (ADVP (RB too))))))))))))',
#   '(ROOT (S (NP (PRP I)) (VP (VBD did) (ADVP (IN that) (DT all)) (PP (IN through) (NP (NN college))) (SBAR (CC but) (S (NP (PRP it)) (ADVP (RB never)) (VP (VBD worked)))))))',
#   'yeah i know and i did that all through college and it worked too',
#   'I did that all through college but it never worked ',
#   '101415',
#   '101415c',
#   'telephone',
#   'contradiction',
#   'contradiction',
#   'contradiction',
#   'contradiction',
#   'contradiction'],
#  ['neutral',
#   "( ( ( ( ( Calcutta ( seems ( to ( be ( ( the ( only ( other ( production center ) ) ) ) ( ( having ( any pretensions ) ) ( to ( ( artistic creativity ) ( at all ) ) ) ) ) ) ) ) ) , ) but ) ( ironically ( you ( ( 're actually ) ( ( more ( likely ( to ( see ( ( the works ) ( of ( ( ( Satyajit Ray ) or ) ( ( Mrinal Sen ) ( shown ( in ( Europe ( or ( North America ) ) ) ) ) ) ) ) ) ) ) ) ) ( than ( in ( India itself ) ) ) ) ) ) ) ) . )",
#   "( ( Most ( of ( ( Mrinal ( Sen 's ) ) work ) ) ) ( ( can ( be ( found ( in ( European collections ) ) ) ) ) . ) )",
#   "(ROOT (S (S (NP (NNP Calcutta)) (VP (VBZ seems) (S (VP (TO to) (VP (VB be) (NP (NP (DT the) (JJ only) (JJ other) (NN production) (NN center)) (VP (VBG having) (NP (DT any) (NNS pretensions)) (PP (TO to) (NP (NP (JJ artistic) (NN creativity)) (ADVP (IN at) (DT all))))))))))) (, ,) (CC but) (S (ADVP (RB ironically)) (NP (PRP you)) (VP (VBP 're) (ADVP (RB actually)) (ADJP (ADJP (RBR more) (JJ likely) (S (VP (TO to) (VP (VB see) (NP (NP (DT the) (NNS works)) (PP (IN of) (NP (NP (NNP Satyajit) (NNP Ray)) (CC or) (NP (NP (NNP Mrinal) (NNP Sen)) (VP (VBN shown) (PP (IN in) (NP (NNP Europe) (CC or) (NNP North) (NNP America)))))))))))) (ADVP (IN than) (PP (IN in) (S (VP (VBG India) (NP (PRP itself))))))))) (. .)))",
#   "(ROOT (S (NP (NP (JJS Most)) (PP (IN of) (NP (NP (NNP Mrinal) (NNP Sen) (POS 's)) (NN work)))) (VP (MD can) (VP (VB be) (VP (VBN found) (PP (IN in) (NP (JJ European) (NNS collections)))))) (. .)))",
#   "Calcutta seems to be the only other production center having any pretensions to artistic creativity at all, but ironically you're actually more likely to see the works of Satyajit Ray or Mrinal Sen shown in Europe or North America than in India itself.",
#   "Most of Mrinal Sen's work can be found in European collections.",
#   '93958',
#   '93958n',
#   'travel',
#   'neutral',
#   'neutral',
#   'entailment',
#   'neutral',
#   'neutral'],
#  ['contradiction',
#   '( ( If ( ( that investor ) ( were ( willing ( to ( pay ( extra ( for ( ( the security ) ( of ( limited downside ) ) ) ) ) ) ) ) ) ) ) ( , ( she ( ( could ( ( buy ( put options ) ) ( with ( ( a ( strike price ) ) ( of ( ( ( $ 98 ) , ) ( which ( would ( ( ( lock ( in ( ( her profit ) ( on ( ( the shares ) ( at ( $ 18 ) ) ) ) ) ) ) , ) ( less ( whatever ( ( the options ) cost ) ) ) ) ) ) ) ) ) ) ) ) . ) ) ) )',
#   '( ( THe ( strike price ) ) ( ( could ( be ( $ 8 ) ) ) . ) )',
#   '(ROOT (S (SBAR (IN If) (S (NP (DT that) (NN investor)) (VP (VBD were) (ADJP (JJ willing) (S (VP (TO to) (VP (VB pay) (NP (NP (JJ extra)) (PP (IN for) (NP (NP (DT the) (NN security)) (PP (IN of) (NP (JJ limited) (NN downside))))))))))))) (, ,) (NP (PRP she)) (VP (MD could) (VP (VB buy) (NP (NN put) (NNS options)) (PP (IN with) (NP (NP (DT a) (NN strike) (NN price)) (PP (IN of) (NP (NP ($ $) (CD 98)) (, ,) (SBAR (WHNP (WDT which)) (S (VP (MD would) (VP (VB lock) (PP (IN in) (NP (NP (PRP$ her) (NN profit)) (PP (IN on) (NP (NP (DT the) (NNS shares)) (PP (IN at) (NP ($ $) (CD 18))))))) (, ,) (ADVP (ADVP (RBR less)) (SBAR (WHNP (WDT whatever)) (S (NP (DT the) (NNS options)) (VP (VBD cost))))))))))))))) (. .)))',
#   '(ROOT (S (NP (NNP THe) (NN strike) (NN price)) (VP (MD could) (VP (VB be) (NP ($ $) (CD 8)))) (. .)))',
#   'If that investor were willing to pay extra for the security of limited downside, she could buy put options with a strike price of $98, which would lock in her profit on the shares at $18, less whatever the options cost.',
#   'THe strike price could be $8.',
#   '12567',
#   '12567c',
#   'slate',
#   'contradiction',
#   'contradiction',
#   'contradiction',
#   'contradiction',
#   'contradiction'],
#  ['neutral',
#   '( ( 3 -RRB- ) ( ( Dare ( you ( ( ( rise ( to ( ( ( ( the occasion ) , ) ( like Raskolnikov ) ) , ) ) ) and ) ( reject ( ( the ( petty rules ) ) ( that ( govern ( lesser men ) ) ) ) ) ) ) ) ? ) )',
#   '( ( ( Would you ) ( ( ( rise up ) and ) ( defeaat ( ( all ( evil lords ) ) ( in ( the town ) ) ) ) ) ) ? )',
#   '(ROOT (S (LST (LS 3) (-RRB- -RRB-)) (VP (VB Dare) (S (NP (PRP you)) (VP (VP (VB rise) (PP (TO to) (NP (NP (DT the) (NN occasion)) (, ,) (PP (IN like) (NP (NNP Raskolnikov))) (, ,)))) (CC and) (VP (VB reject) (NP (NP (DT the) (JJ petty) (NNS rules)) (SBAR (WHNP (WDT that)) (S (VP (VBP govern) (NP (JJR lesser) (NNS men)))))))))) (. ?)))',
#   '(ROOT (SQ (MD Would) (NP (PRP you)) (VP (VP (VB rise) (PRT (RP up))) (CC and) (VP (VB defeaat) (NP (NP (DT all) (JJ evil) (NNS lords)) (PP (IN in) (NP (DT the) (NN town)))))) (. ?)))',
#   '3)  Dare you rise to the occasion, like Raskolnikov, and reject the petty rules that govern lesser men?',
#   'Would you rise up and defeaat all evil lords in the town?',
#   '117487',
#   '117487n',
#   'slate',
#   'neutral',
#   'neutral',
#   'neutral',
#   'neutral',
#   'neutral'],
#  ['contradiction',
#   '( ( The ( ( most important ) directions ) ) ( ( ( are ( simply ( ( up and ) up ) ) ) ( ( ( ( ( ( ( ( leads eventually ) ( to ( the cathedral ) ) ) and ) ( fortress ( commanding ( the hilltop ) ) ) ) , ) and ) down ) ( inevitably ( ( leads ( to ( one ( of ( three gates ) ) ) ) ) ( through ( ( the wall ) ( to ( the ( new town ) ) ) ) ) ) ) ) ) . ) )',
#   '( Go ( ( downwards ( to ( one ( of ( ( ( the gates ) , ) ( ( all ( of which ) ) ( will ( ( lead you ) ( into ( the cathedral ) ) ) ) ) ) ) ) ) ) . ) )',
#   '(ROOT (S (NP (DT The) (ADJP (RBS most) (JJ important)) (NNS directions)) (VP (VBP are) (PRN (ADVP (RB simply)) (ADVP (RB up) (CC and) (RB up))) (VP (VP (VBZ leads) (ADVP (RB eventually)) (PP (TO to) (NP (DT the) (NN cathedral)))) (CC and) (VP (VBZ fortress) (NP (JJ commanding) (DT the) (NN hilltop))) (, ,) (CC and) (ADVP (RB down)) (VP (ADVP (RB inevitably)) (VBZ leads) (PP (TO to) (NP (NP (CD one)) (PP (IN of) (NP (CD three) (NNS gates))))) (PP (IN through) (NP (NP (DT the) (NN wall)) (PP (TO to) (NP (DT the) (JJ new) (NN town)))))))) (. .)))',
#   '(ROOT (S (NP (NNP Go)) (VP (VBZ downwards) (PP (TO to) (NP (NP (CD one)) (PP (IN of) (NP (NP (DT the) (NNS gates)) (, ,) (SBAR (WHNP (DT all) (WHPP (IN of) (WHNP (WDT which)))) (S (VP (MD will) (VP (VB lead) (NP (PRP you)) (PP (IN into) (NP (DT the) (NN cathedral)))))))))))) (. .)))',
#   'The most important directions are simply up and up leads eventually to the cathedral and fortress commanding the hilltop, and down inevitably leads to one of three gates through the wall to the new town.',
#   'Go downwards to one of the gates, all of which will lead you into the cathedral.',
#   '9616',
#   '9616c',
#   'travel',
#   'contradiction',
#   'contradiction',
#   'entailment',
#   'contradiction',
#   'contradiction'],
#  ['contradiction',
#   '( ( ( The ( bhakti movement ) ) ( of ( the Tamils ) ) ) ( ( ( brought ( a ( new warmth ) ) ) ( to ( ( the ( hitherto ( rigid ( Brahmanic ritual ) ) ) ) ( of Hinduism ) ) ) ) . ) )',
#   "( ( ( The ( Tamils ' ) ) ( bhakti movement ) ) ( ( froze ( ( the ( ( previously warm ) ritual ) ) ( of Hinduism ) ) ) . ) )",
#   '(ROOT (S (NP (NP (DT The) (JJ bhakti) (NN movement)) (PP (IN of) (NP (DT the) (NNPS Tamils)))) (VP (VBD brought) (NP (DT a) (JJ new) (NN warmth)) (PP (TO to) (NP (NP (DT the) (JJ hitherto) (JJ rigid) (JJ Brahmanic) (NN ritual)) (PP (IN of) (NP (NNP Hinduism)))))) (. .)))',
#   "(ROOT (S (NP (NP (DT The) (NNPS Tamils) (POS ')) (NN bhakti) (NN movement)) (VP (VBD froze) (NP (NP (DT the) (ADJP (RB previously) (JJ warm)) (NN ritual)) (PP (IN of) (NP (NNP Hinduism))))) (. .)))",
#   'The bhakti movement of the Tamils brought a new warmth to the hitherto rigid Brahmanic ritual of Hinduism.',
#   "The Tamils' bhakti movement froze the previously warm ritual of Hinduism.",
#   '119637',
#   '119637c',
#   'travel',
#   'contradiction',
#   'contradiction',
#   'contradiction',
#   'contradiction',
#   'entailment'],
#  ['contradiction',
#   "( ( ( ( see now ) ( in ( ( ( ( ( ( a situation ) ( like ( that ( ( the boys ) ( are ( ( only ( sixteen years ) ) old ) ) ) ) ) ) and ) ( they ( ( were sexually ) ( involved ( with her ) ) ) ) ) and ) ( i ( think ( like ( ( ( ( at ( that ( particular point ) ) ) ( she ( was ( ( twenty three ) ( you ( know ( so ( she ( ( ( was n't ) really ) ( ( that ( much older ) ) ( than them ) ) ) ) ) ) ) ) ) ) ) and ) ( ( being ( ( a boy ) ( ( at ( that age ) ) ( i ( think ( that ( they ( 're ( very um ) ) ) ) ) ) ) ) ) ( you ( know ( ( let 's ) face ) ) ) ) ) ) ) ) ) ) ) it ) ( that ( ( 's ( at ( ( a point ) ( in ( your life ) ) ) ) ) ( ( when you ) ( you ( ( 're just ) ( starting ( to ( realize ( ( all ( the things ) ) ( of life ) ) ) ) ) ) ) ) ) ) )",
#   '( ( Everyone involved ) ( ( was ( the ( same age ) ) ) . ) )',
#   "(ROOT (SINV (VP (VBP see) (ADVP (RB now)) (PP (IN in) (S (S (NP (DT a) (NN situation)) (VP (VBP like) (SBAR (IN that) (S (NP (DT the) (NNS boys)) (VP (VBP are) (ADJP (NP (RB only) (CD sixteen) (NNS years)) (JJ old))))))) (CC and) (S (NP (PRP they)) (VP (VBD were) (ADVP (RB sexually)) (VP (VBN involved) (PP (IN with) (NP (PRP her)))))) (CC and) (S (NP (FW i)) (VP (VBP think) (SBAR (IN like) (S (S (PP (IN at) (NP (DT that) (JJ particular) (NN point))) (NP (PRP she)) (VP (VBD was) (NP (NP (CD twenty) (CD three)) (SBAR (S (NP (PRP you)) (VP (VBP know) (SBAR (IN so) (S (NP (PRP she)) (VP (VBD was) (RB n't) (ADVP (RB really)) (ADJP (ADJP (DT that) (RB much) (JJR older)) (PP (IN than) (NP (PRP them))))))))))))) (CC and) (S (S (VP (VBG being) (NP (NP (DT a) (NN boy)) (SBAR (WHPP (IN at) (WHNP (WDT that) (NN age))) (S (NP (FW i)) (VP (VBP think) (SBAR (IN that) (S (NP (PRP they)) (VP (VBP 're) (ADJP (RB very) (JJ um))))))))))) (NP (PRP you)) (VP (VBP know) (NP (NP (NNP let) (POS 's)) (NN face))))))))))) (NP (PRP it)) (SBAR (WHNP (WDT that)) (S (VP (VBZ 's) (PP (IN at) (NP (NP (DT a) (NN point)) (PP (IN in) (NP (PRP$ your) (NN life))))) (SBAR (WHADVP (WRB when) (NP (PRP you))) (S (NP (PRP you)) (VP (VBP 're) (ADVP (RB just)) (VP (VBG starting) (S (VP (TO to) (VP (VB realize) (NP (NP (PDT all) (DT the) (NNS things)) (PP (IN of) (NP (NN life))))))))))))))))",
#   '(ROOT (S (NP (NP (NN Everyone)) (VP (VBN involved))) (VP (VBD was) (NP (DT the) (JJ same) (NN age))) (. .)))',
#   "see now in a situation like that the boys are only sixteen years old and they were sexually involved with her and i think like at that particular point she was twenty three you know so she wasn't really that much older than them and being a boy at that age i think that they're very um you know let's face it that's at a point in your life when you you're just starting to realize all the things of life",
#   'Everyone involved was the same age.',
#   '55658',
#   '55658c',
#   'telephone',
#   'contradiction',
#   'contradiction',
#   'contradiction',
#   'contradiction',
#   'contradiction'],
#  ['entailment',
#   '( ( ( ( You and ) ( your friends ) ) ( ( ( are not ) welcome ) here ) ) ( , ( ( said Severn ) . ) ) )',
#   '( Severn ( ( said ( ( the people ) ( ( were ( not welcome ) ) there ) ) ) . ) )',
#   '(ROOT (SINV (S (NP (NP (PRP You)) (CC and) (NP (PRP$ your) (NNS friends))) (VP (VBP are) (RB not) (ADJP (JJ welcome)) (ADVP (RB here)))) (, ,) (VP (VBD said)) (NP (NNP Severn)) (. .)))',
#   '(ROOT (S (NP (NNP Severn)) (VP (VBD said) (SBAR (S (NP (DT the) (NNS people)) (VP (VBD were) (ADJP (RB not) (JJ welcome)) (ADVP (RB there)))))) (. .)))',
#   'You and your friends are not welcome here, said Severn.',
#   'Severn said the people were not welcome there.',
#   '73734',
#   '73734e',
#   'fiction',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment'],
#  ['neutral',
#   "( ( ( um-hum ( um-hum yeah ) ) ( ( ( ( well uh ) ( i ( can ( ( see ( you ( know ( it ( 's ( it ( 's ( it ( 's ( ( ( it 's ) kind ) ( of ( ( funny ( because ( we ( it ( ( seems ( like we ) ) ( ( loan money ) ( you ( know we ) ) ) ) ) ) ) ) money ) ) ) ) ) ) ) ) ) ) ) ) ( with ( strings attached ) ) ) ) ) ) and ) ( ( if ( ( ( ( the ( government changes ) ) and ) ( ( the country ) ( that ( we ( loan ( the ( money ( to ( um i ) ) ) ) ) ) ) ) ) ( can ( see ( why ( ( the might ) ( have ( ( a ( different attitude ) ) ( towards ( paying it ) ) ) ) ) ) ) ) ) ) ( back ( it ( 's ( a lot ) ) ) ) ) ) ) ( us ( that ( you ( know ( we ( ( do n't ) ( really ( ( ( loan money ) ( to ( to countries ) ) ) ( ( ( we ( ( loan money ) ( to governments ) ) ) and ) ( it ( 's the ) ) ) ) ) ) ) ) ) ) ) )",
#   "( We ( ( ( do n't ) ( loan ( ( a lot ) ( of money ) ) ) ) . ) )",
#   "(ROOT (FRAG (NP (NP (JJ um-hum) (JJ um-hum) (NN yeah)) (SBAR (S (S (INTJ (UH well) (UH uh)) (NP (FW i)) (VP (MD can) (VP (VB see) (SBAR (S (NP (PRP you)) (VP (VBP know) (SBAR (S (NP (PRP it)) (VP (VBZ 's) (SBAR (S (NP (PRP it)) (VP (VBZ 's) (SBAR (S (NP (PRP it)) (VP (VBZ 's) (NP (NP (NP (PRP it) (POS 's)) (NN kind)) (PP (IN of) (NP (ADJP (JJ funny) (PP (IN because) (NP (NP (PRP we)) (SBAR (S (NP (PRP it)) (VP (VBZ seems) (PP (IN like) (NP (PRP we))) (NP (NP (NN loan) (NN money)) (SBAR (S (NP (PRP you)) (VP (VBP know) (NP (PRP we)))))))))))) (NN money)))))))))))))))) (PP (IN with) (NP (NP (NNS strings)) (VP (VBN attached))))))) (CC and) (S (SBAR (IN if) (S (NP (NP (DT the) (NN government) (NNS changes)) (CC and) (NP (NP (DT the) (NN country)) (SBAR (IN that) (S (NP (PRP we)) (VP (VB loan) (NP (DT the) (NN money) (S (VP (TO to) (VP (VB um) (NP (FW i))))))))))) (VP (MD can) (VP (VB see) (SBAR (WHADVP (WRB why)) (S (NP (DT the) (NN might)) (VP (VBP have) (NP (NP (DT a) (JJ different) (NN attitude)) (PP (IN towards) (S (VP (VBG paying) (NP (PRP it))))))))))))) (ADVP (RB back)) (NP (PRP it)) (VP (VBZ 's) (NP (DT a) (NN lot))))))) (X (NP (PRP us)) (SBAR (IN that) (S (NP (PRP you)) (VP (VBP know) (SBAR (S (NP (PRP we)) (VP (VBP do) (RB n't) (VP (ADVP (RB really)) (VB loan) (NP (NN money)) (PP (TO to) (PP (TO to) (NP (NNS countries)))) (SBAR (S (S (NP (PRP we)) (NP (NP (NN loan) (NN money)) (PP (TO to) (NP (NNS governments))))) (CC and) (S (NP (PRP it)) (VP (VBZ 's) (NP (DT the))))))))))))))))",
#   "(ROOT (S (NP (PRP We)) (VP (VBP do) (RB n't) (VP (VB loan) (NP (NP (DT a) (NN lot)) (PP (IN of) (NP (NN money)))))) (. .)))",
#   "um-hum um-hum yeah well uh i can see you know it's it's it's it's kind of funny because we it seems like we loan money you know we money with strings attached and if the government changes and the country that we loan the money to um i can see why the might have a different attitude towards paying it back it's a lot us that  you know we don't really loan money to to countries we loan money to governments and it's the",
#   "We don't loan a lot of money.",
#   '50830',
#   '50830c',
#   'telephone',
#   'contradiction',
#   'neutral',
#   'contradiction',
#   'neutral',
#   'neutral'],
#  ['entailment',
#   "( i ( ( 'm not ) ( sure ( what ( ( the ( overnight low ) ) was ) ) ) ) )",
#   "( I ( ( ( do n't ) ( know ( ( how cold ) ( it ( got ( last night ) ) ) ) ) ) . ) )",
#   "(ROOT (S (NP (FW i)) (VP (VBP 'm) (RB not) (ADJP (JJ sure) (SBAR (WHNP (WP what)) (S (NP (DT the) (JJ overnight) (NN low)) (VP (VBD was))))))))",
#   "(ROOT (S (NP (PRP I)) (VP (VBP do) (RB n't) (VP (VB know) (SBAR (WHADJP (WRB how) (JJ cold)) (S (NP (PRP it)) (VP (VBD got) (NP (JJ last) (NN night))))))) (. .)))",
#   "i'm not sure what the overnight low was",
#   "I don't know how cold it got last night.",
#   '5698',
#   '5698e',
#   'telephone',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment'],
#  ['entailment',
#   '( so ( i ( have ( to ( find ( a ( way ( to ( supplement that ) ) ) ) ) ) ) ) )',
#   '( I ( ( need ( ( a way ) ( to ( add ( something extra ) ) ) ) ) . ) )',
#   '(ROOT (SBAR (IN so) (S (NP (FW i)) (VP (VBP have) (S (VP (TO to) (VP (VB find) (NP (DT a) (NN way) (S (VP (TO to) (VP (VB supplement) (NP (DT that)))))))))))))',
#   '(ROOT (S (NP (PRP I)) (VP (VBP need) (S (NP (DT a) (NN way)) (VP (TO to) (VP (VB add) (NP (NN something) (JJ extra)))))) (. .)))',
#   'so i have to find a way to supplement that',
#   'I need a way to add something extra.',
#   '70726',
#   '70726e',
#   'telephone',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment'],
#  ['entailment',
#   "( ( ( ( ( ( ( ( the hologram ) ( ( makes up ) ( all ( these things ) ) ) ) and ) ( uh ( i ( mean ( sometimes ( sometimes ( it ( 's ( ( funny sometimes ) ( it ( 's not ) ) ) ) ) ) ) ) ) ) ) but ) ( uh ( you ( know ( ( ( ( it 's ) ( something ( to ( ( pass ( the time ) ) ( until ( we do ) ) ) ) ) ) and ) then ) ) ) ) ) and ) ( then ( we ( watch football ) ) ) )",
#   '( Sometimes ( it ( ( is ( amusing ( to ( see ( what ( ( the hologram ) creates ) ) ) ) ) ) . ) ) )',
#   "(ROOT (S (S (S (NP (DT the) (NN hologram)) (VP (VBZ makes) (PRT (RP up)) (NP (PDT all) (DT these) (NNS things)))) (CC and) (S (INTJ (UH uh)) (NP (FW i)) (VP (VBP mean) (S (ADVP (RB sometimes)) (ADVP (RB sometimes)) (NP (PRP it)) (VP (VBZ 's) (ADJP (JJ funny) (RB sometimes) (SBAR (S (NP (PRP it)) (VP (VBZ 's) (RB not)))))))))) (CC but) (S (INTJ (UH uh)) (NP (PRP you)) (VP (VBP know) (NP (NP (NP (PRP it) (POS 's)) (NN something) (S (VP (TO to) (VP (VB pass) (NP (DT the) (NN time)) (SBAR (IN until) (S (NP (PRP we)) (VP (VBP do)))))))) (CC and) (ADVP (RB then))))) (CC and) (S (ADVP (RB then)) (NP (PRP we)) (VP (VBP watch) (NP (NN football))))))",
#   '(ROOT (S (ADVP (RB Sometimes)) (NP (PRP it)) (VP (VBZ is) (ADJP (JJ amusing) (S (VP (TO to) (VP (VB see) (SBAR (WHNP (WP what)) (S (NP (DT the) (NN hologram)) (VP (VBZ creates))))))))) (. .)))',
#   "the hologram makes up all these things and uh i mean sometimes  sometimes it's funny sometimes it's not but uh you know it's something to pass the time until we do and then and then we watch football",
#   'Sometimes it is amusing to see what the hologram creates.',
#   '138302',
#   '138302e',
#   'telephone',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment'],
#  ['neutral',
#   '( ( ( 5 ( The share ) ) ( of ( ( gross ( national saving ) ) ( used ( to ( replace ( depreciated capital ) ) ) ) ) ) ) ( ( has ( increased ( over ( the ( past ( 40 years ) ) ) ) ) ) . ) )',
#   '( ( Gross ( national saving ) ) ( ( was ( highest ( this year ) ) ) . ) )',
#   '(ROOT (S (NP (NP (NP (CD 5)) (NP (DT The) (NN share))) (PP (IN of) (NP (NP (JJ gross) (JJ national) (NN saving)) (VP (VBN used) (S (VP (TO to) (VP (VB replace) (NP (JJ depreciated) (NN capital))))))))) (VP (VBZ has) (VP (VBN increased) (PP (IN over) (NP (DT the) (JJ past) (CD 40) (NNS years))))) (. .)))',
#   '(ROOT (S (NP (NNP Gross) (JJ national) (NN saving)) (VP (VBD was) (NP (NP (JJS highest)) (NP (DT this) (NN year)))) (. .)))',
#   '5 The share of gross national saving used to replace depreciated capital has increased over the past 40 years.',
#   'Gross national saving was highest this year.',
#   '113628',
#   '113628n',
#   'government',
#   'neutral',
#   'neutral',
#   'neutral',
#   'neutral',
#   'neutral'],
#  ['contradiction',
#   '( ( So far ) ( , ( however ( , ( ( ( the number ) ( of ( ( mail pieces ) ( lost ( to ( alternative ( bill-paying methods ) ) ) ) ) ) ) ( ( ( is ( too small ) ) ( to ( have ( ( any ( material impact ) ) ( on ( First-Class volume ) ) ) ) ) ) . ) ) ) ) ) )',
#   '( ( ( The amount ) ( of ( lost mail ) ) ) ( ( ( is huge ) and ) ( really ( impacts ( mail volume ) ) ) ) )',
#   '(ROOT (S (ADVP (IN So) (RB far)) (, ,) (ADVP (RB however)) (, ,) (NP (NP (DT the) (NN number)) (PP (IN of) (NP (NP (NN mail) (NNS pieces)) (VP (VBN lost) (PP (TO to) (NP (JJ alternative) (JJ bill-paying) (NNS methods))))))) (VP (VBZ is) (ADJP (RB too) (JJ small)) (S (VP (TO to) (VP (VB have) (NP (NP (DT any) (NN material) (NN impact)) (PP (IN on) (NP (NNP First-Class) (NN volume)))))))) (. .)))',
#   '(ROOT (S (NP (NP (DT The) (NN amount)) (PP (IN of) (NP (VBN lost) (NN mail)))) (VP (VP (VBZ is) (ADJP (JJ huge))) (CC and) (VP (ADVP (RB really)) (VBZ impacts) (NP (NN mail) (NN volume))))))',
#   'So far, however, the number of mail pieces lost to alternative bill-paying methods is too small to have any material impact on First-Class volume.',
#   'The amount of lost mail is huge and really impacts mail volume',
#   '56582',
#   '56582c',
#   'government',
#   'contradiction',
#   'contradiction',
#   'contradiction',
#   'contradiction',
#   'contradiction'],
#  ['neutral',
#   '( you ( want ( to ( ( ( punch ( the button ) ) and ) go ) ) ) )',
#   "( You ( ( ( do n't ) ( want ( to ( ( ( ( ( push ( the button ) ) lightly ) , ) ( but rather ) ) ( punch ( it hard ) ) ) ) ) ) . ) )",
#   '(ROOT (S (NP (PRP you)) (VP (VBP want) (S (VP (TO to) (VP (VP (VB punch) (NP (DT the) (NN button))) (CC and) (VP (VB go))))))))',
#   "(ROOT (S (NP (PRP You)) (VP (VBP do) (RB n't) (VP (VB want) (S (VP (TO to) (VP (VP (VB push) (NP (DT the) (NN button)) (ADVP (RB lightly))) (, ,) (CONJP (CC but) (RB rather)) (VP (VB punch) (S (NP (PRP it)) (ADJP (JJ hard))))))))) (. .)))",
#   'you want to punch the button and go',
#   "You don't want to push the button lightly, but rather punch it hard.",
#   '20648',
#   '20648n',
#   'telephone',
#   'neutral',
#   'neutral',
#   'contradiction',
#   'entailment',
#   'neutral'],
#  ['entailment',
#   '( ( ( Buffet and ) ( a la ) ) ( ( carte available ) . ) )',
#   '( It ( ( has ( a buffet ) ) . ) )',
#   '(ROOT (S (NP (NP (NNP Buffet)) (CC and) (NP (DT a) (NNP la))) (VP (VBP carte) (ADJP (JJ available))) (. .)))',
#   '(ROOT (S (NP (PRP It)) (VP (VBZ has) (NP (DT a) (NN buffet))) (. .)))',
#   'Buffet and a\xa0 la carte available.',
#   'It has a buffet.',
#   '75259',
#   '75259e',
#   'travel',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment'],
#  ['neutral',
#   '( Blue ( ( says ( Blumenthal ( claimed ( Clinton ( had ( ( told him ) ( that ( Lewinsky ( had ( made ( unwanted ( sexual advances ) ) ) ) ) ) ) ) ) ) ) ) . ) )',
#   '( Clinton ( ( said ( that ( ( Monica Lewinsky ) ( ( ( made ( unwanted ( sexual advances ) ) ) ( during ( her time ) ) ) ( as ( ( a journalist ) ( in ( the ( White House ) ) ) ) ) ) ) ) ) . ) )',
#   '(ROOT (S (NP (NNP Blue)) (VP (VBZ says) (SBAR (S (NP (NNP Blumenthal)) (VP (VBD claimed) (SBAR (S (NP (NNP Clinton)) (VP (VBD had) (VP (VBN told) (NP (PRP him)) (SBAR (IN that) (S (NP (NNP Lewinsky)) (VP (VBD had) (VP (VBN made) (NP (JJ unwanted) (JJ sexual) (NNS advances)))))))))))))) (. .)))',
#   '(ROOT (S (NP (NNP Clinton)) (VP (VBD said) (SBAR (IN that) (S (NP (NNP Monica) (NNP Lewinsky)) (VP (VBD made) (NP (JJ unwanted) (JJ sexual) (NNS advances)) (PP (IN during) (NP (PRP$ her) (NN time))) (PP (IN as) (NP (NP (DT a) (NN journalist)) (PP (IN in) (NP (DT the) (NNP White) (NNP House))))))))) (. .)))',
#   'Blue says Blumenthal claimed Clinton had told him that Lewinsky had made unwanted sexual advances.',
#   'Clinton said that Monica Lewinsky made unwanted sexual advances during her time as a journalist in the White House. ',
#   '108934',
#   '108934n',
#   'slate',
#   'neutral',
#   'neutral',
#   'entailment',
#   'neutral',
#   'neutral'],
#  ['neutral',
#   '( We ( also ( ( have ( found ( that ( ( leading organizations ) ( strive ( to ( ensure ( that ( ( their core ) ( ( processes ( ( efficiently and ) effectively ) ) ( support ( mission-related outcomes ) ) ) ) ) ) ) ) ) ) ) ) . ) ) )',
#   '( ( Leading organizations ) ( ( want ( to ( be ( sure ( ( their employees ) ( are safe ) ) ) ) ) ) . ) )',
#   '(ROOT (S (NP (PRP We)) (ADVP (RB also)) (VP (VBP have) (VP (VBN found) (SBAR (IN that) (S (NP (VBG leading) (NNS organizations)) (VP (VBP strive) (S (VP (TO to) (VP (VB ensure) (SBAR (IN that) (S (NP (PRP$ their) (NN core)) (VP (VBZ processes) (ADVP (RB efficiently) (CC and) (RB effectively)) (VP (VB support) (NP (JJ mission-related) (NNS outcomes)))))))))))))) (. .)))',
#   '(ROOT (S (NP (VBG Leading) (NNS organizations)) (VP (VBP want) (S (VP (TO to) (VP (VB be) (ADJP (JJ sure) (SBAR (S (NP (PRP$ their) (NNS employees)) (VP (VBP are) (ADJP (JJ safe)))))))))) (. .)))',
#   'We also have found that leading organizations strive to ensure that their core processes efficiently and effectively support mission-related outcomes.',
#   'Leading organizations want to be sure their employees are safe.',
#   '130680',
#   '130680c',
#   'government',
#   'contradiction',
#   'neutral',
#   'neutral',
#   'neutral',
#   'neutral'],
#  ['neutral',
#   "( oh ( ( uh-huh ( well ( no ( ( they ( would n't ) ) ( would they ) ) ) ) ) no ) )",
#   "( No ( , ( they ( ( ( would n't ) ( go there ) ) . ) ) ) )",
#   "(ROOT (SINV (FRAG (INTJ (UH oh))) (VP (VBZ uh-huh) (ADVP (RB well) (RB no) (SBAR (SINV (S (NP (PRP they)) (VP (MD would) (RB n't))) (VP (MD would)) (NP (PRP they)))))) (NP (RB no))))",
#   "(ROOT (S (INTJ (UH No)) (, ,) (NP (PRP they)) (VP (MD would) (RB n't) (VP (VB go) (ADVP (RB there)))) (. .)))",
#   "oh uh-huh well no they wouldn't would they no",
#   "No, they wouldn't go there.",
#   '143945',
#   '143945n',
#   'telephone',
#   'neutral',
#   'neutral',
#   'neutral',
#   'neutral',
#   'neutral'],
#  ['contradiction',
#   "( Sorry ( but ( ( that ( 's ( how ( it is ) ) ) ) . ) ) )",
#   '( This ( ( is ( how ( things ( ( are and ) ( there ( are ( ( no apologies ) ( about it ) ) ) ) ) ) ) ) . ) )',
#   "(ROOT (FRAG (ADVP (RB Sorry)) (SBAR (CC but) (WHNP (WDT that)) (S (VP (VBZ 's) (SBAR (WHADVP (WRB how)) (S (NP (PRP it)) (VP (VBZ is)))))) (. .))))",
#   '(ROOT (S (NP (DT This)) (VP (VBZ is) (SBAR (WHADVP (WRB how)) (S (NP (NNS things)) (VP (VP (VBP are)) (CC and) (VP (ADVP (RB there)) (VBP are) (NP (NP (DT no) (NNS apologies)) (PP (IN about) (NP (PRP it))))))))) (. .)))',
#   "Sorry but that's how it is.",
#   'This is how things are and there are no apologies about it.',
#   '67610',
#   '67610c',
#   'fiction',
#   'contradiction',
#   'contradiction',
#   'neutral',
#   'contradiction',
#   'entailment'],
#  ['neutral',
#   "( ( ( Not quite ) ( as large ) ) ( ( ( is ( the ( Papal Crose ) ) ) ( commemorating ( ( ( ( ( Pope ( John ( Paul ( II 's ) ) ) ) visit ) ( in 1979 ) ) , ) ( when ( ( ( more ( ( than one ) million ) ) people ) ( gathered ( to ( celebrate mass ) ) ) ) ) ) ) ) . ) )",
#   '( ( Pope ( John ( Paul II ) ) ) ( also ( ( visited ( in 1983 ) ) . ) ) )',
#   "(ROOT (SINV (ADVP (ADVP (RB Not) (RB quite)) (PP (IN as) (ADJP (JJ large)))) (VBZ is) (NP (DT the) (NNP Papal) (NNP Crose)) (VP (VBG commemorating) (NP (NP (NP (NNP Pope) (NNP John) (NNP Paul) (NNP II) (POS 's)) (NN visit)) (PP (IN in) (NP (CD 1979))) (, ,) (SBAR (WHADVP (WRB when)) (S (NP (QP (JJR more) (IN than) (CD one) (CD million)) (NNS people)) (VP (VBD gathered) (S (VP (TO to) (VP (VB celebrate) (NP (NN mass)))))))))) (. .)))",
#   '(ROOT (S (NP (NNP Pope) (NNP John) (NNP Paul) (NNP II)) (ADVP (RB also)) (VP (VBD visited) (PP (IN in) (NP (CD 1983)))) (. .)))',
#   "Not quite as large is the Papal Crose commemorating Pope John Paul II's visit in 1979, when more than one million people gathered to celebrate mass.",
#   'Pope John Paul II also visited in 1983.',
#   '90965',
#   '90965n',
#   'travel',
#   'neutral',
#   'neutral',
#   'neutral',
#   'neutral',
#   'neutral'],
#  ['contradiction',
#   '( ( ( ( ( ( The ( tourist industry ) ) ( continued ( to expand ) ) ) , ) and ) ( ( though ( it ( became ( one ( of ( ( the ( top ( two ( income earners ) ) ) ) ( in Spain ) ) ) ) ) ) ) ( , ( ( ( a realization ) ( that ( unrestricted ( ( mass tourism ) ( was ( leading ( to ( damaging ( long-term consequences ) ) ) ) ) ) ) ) ) ( also ( began ( to grow ) ) ) ) ) ) ) . )',
#   '( Tourism ( ( ( is not ) ( very ( big ( in Spain ) ) ) ) . ) )',
#   '(ROOT (S (S (NP (DT The) (NN tourist) (NN industry)) (VP (VBD continued) (S (VP (TO to) (VP (VB expand)))))) (, ,) (CC and) (S (SBAR (IN though) (S (NP (PRP it)) (VP (VBD became) (NP (NP (CD one)) (PP (IN of) (NP (NP (DT the) (JJ top) (CD two) (NN income) (NNS earners)) (PP (IN in) (NP (NNP Spain))))))))) (, ,) (NP (NP (DT a) (NN realization)) (SBAR (WHNP (WDT that)) (S (VP (VBD unrestricted) (SBAR (S (NP (JJ mass) (NN tourism)) (VP (VBD was) (VP (VBG leading) (PP (TO to) (NP (JJ damaging) (JJ long-term) (NNS consequences))))))))))) (ADVP (RB also)) (VP (VBD began) (S (VP (TO to) (VP (VB grow)))))) (. .)))',
#   '(ROOT (S (NP (NNP Tourism)) (VP (VBZ is) (RB not) (ADJP (RB very) (JJ big) (PP (IN in) (NP (NNP Spain))))) (. .)))',
#   'The tourist industry continued to expand, and though it became one of the top two income earners in Spain, a realization that unrestricted mass tourism was leading to damaging long-term consequences also began to grow.',
#   'Tourism is not very big in Spain.',
#   '33530',
#   '33530c',
#   'travel',
#   'contradiction',
#   'contradiction',
#   'contradiction',
#   'contradiction',
#   'contradiction'],
#  ['neutral',
#   "( She ( ( seemed so ) ( different '' ) ) )",
#   "( She ( ( had ( ( changed ( a lot ) ) ( since ( ( the ( last time ) ) ( we ( 'd ( seen her ) ) ) ) ) ) ) . ) )",
#   "(ROOT (S (NP (PRP She)) (VP (VBD seemed) (ADVP (RB so)) (ADJP (JJ different) ('' '')))))",
#   "(ROOT (S (NP (PRP She)) (VP (VBD had) (VP (VBN changed) (NP (DT a) (NN lot)) (PP (IN since) (NP (NP (DT the) (JJ last) (NN time)) (SBAR (S (NP (PRP we)) (VP (VBD 'd) (VP (VBN seen) (NP (PRP her)))))))))) (. .)))",
#   'She seemed so different  "',
#   "She had changed a lot since the last time we'd seen her.",
#   '14083',
#   '14083n',
#   'fiction',
#   'neutral',
#   'neutral',
#   'neutral',
#   'entailment',
#   'neutral'],
#  ['neutral',
#   "( i ( ( 'm not ) ( ( opposed ( to it ) ) ( but ( when ( ( its ( when ( ( the time ) ( is ( right ( it ( ( will probably ) ( ( just ( kind of ) ) ( happen you ) ) ) ) ) ) ) ) ) know ) ) ) ) ) )",
#   '( I ( ( ( can not ) ( wait ( for ( it ( to happen ) ) ) ) ) . ) )',
#   "(ROOT (S (NP (FW i)) (VP (VBP 'm) (RB not) (VP (VBN opposed) (PP (TO to) (NP (PRP it))) (PRN (CC but) (SBAR (WHADVP (WRB when)) (S (NP (NP (PRP$ its)) (SBAR (WHADVP (WRB when)) (S (NP (DT the) (NN time)) (VP (VBZ is) (ADJP (JJ right) (SBAR (S (NP (PRP it)) (VP (MD will) (ADVP (RB probably)) (VP (ADVP (JJ just) (NN kind) (IN of)) (VB happen) (NP (PRP you))))))))))) (VP (VBP know)))))))))",
#   '(ROOT (S (NP (PRP I)) (VP (MD can) (RB not) (VP (VB wait) (SBAR (IN for) (S (NP (PRP it)) (VP (TO to) (VP (VB happen))))))) (. .)))',
#   "i'm not opposed to it but when its when the time is right it will probably just kind of happen you know",
#   'I cannot wait for it to happen.',
#   '47639',
#   '47639c',
#   'telephone',
#   'contradiction',
#   'neutral',
#   'contradiction',
#   'neutral',
#   'neutral'],
#  ['entailment',
#   '( ( ( The census ) ( of 1931 ) ) ( ( ( served ( as ( an ( alarm signal ) ) ) ) ( for ( the ( Malay ( national consciousness ) ) ) ) ) . ) )',
#   '( ( The ( 1931 ( Malay census ) ) ) ( ( was ( an ( alarm bell ) ) ) . ) )',
#   '(ROOT (S (NP (NP (DT The) (NN census)) (PP (IN of) (NP (CD 1931)))) (VP (VBD served) (PP (IN as) (NP (DT an) (NN alarm) (NN signal))) (PP (IN for) (NP (DT the) (NNP Malay) (JJ national) (NN consciousness)))) (. .)))',
#   '(ROOT (S (NP (DT The) (NNP 1931) (NNP Malay) (NN census)) (VP (VBD was) (NP (DT an) (NN alarm) (NN bell))) (. .)))',
#   'The census of 1931 served as an alarm signal for the Malay national consciousness.',
#   'The 1931 Malay census was an alarm bell.',
#   '100241',
#   '100241e',
#   'travel',
#   'entailment',
#   'entailment',
#   'contradiction',
#   'entailment',
#   'entailment'],
#  ['entailment',
#   '( ( ( Mortifyingly enough ) ( , ( it ( is ( all ( ( ( ( ( ( ( the difficulty ) , ) ( the laziness ) ) , ) ( ( the ( pathetic formlessness ) ) ( in youth ) ) ) , ) ( ( the ( round peg ) ) ( in ( the ( square hole ) ) ) ) ) ) ) ) ) ) ( , ( ( the whatever ) ( ( do ( you want ) ) ? ) ) ) )',
#   '( ( Many youth ) ( ( are lazy ) . ) )',
#   '(ROOT (S (S (S (ADJP (RB Mortifyingly) (JJ enough))) (, ,) (NP (PRP it)) (VP (VBZ is) (NP (PDT all) (NP (NP (DT the) (NN difficulty)) (, ,) (NP (DT the) (NNS laziness))) (, ,) (NP (NP (DT the) (ADJP (JJ pathetic)) (NNS formlessness)) (PP (IN in) (NP (NN youth)))) (, ,) (NP (NP (DT the) (NN round) (NN peg)) (PP (IN in) (NP (DT the) (JJ square) (NN hole))))))) (, ,) (NP (DT the) (NN whatever)) (VP (VBP do) (SBAR (S (NP (PRP you)) (VP (VBP want))))) (. ?)))',
#   '(ROOT (S (NP (JJ Many) (NN youth)) (VP (VBP are) (ADJP (JJ lazy))) (. .)))',
#   'Mortifyingly enough, it is all  the difficulty, the laziness, the pathetic formlessness in youth, the round peg in the square hole, the whatever do you want?',
#   'Many youth are lazy.',
#   '114458',
#   '114458e',
#   'slate',
#   'entailment',
#   'neutral',
#   'entailment',
#   'neutral',
#   'entailment'],
#  ['contradiction',
#   '( Conversely ( , ( ( ( an increase ) ( in ( government saving ) ) ) ( ( ( ( adds ( to ( ( the supply ) ( of ( resources ( available ( for investment ) ) ) ) ) ) ) and ) ( may ( ( put ( downward pressure ) ) ( on ( interest rates ) ) ) ) ) . ) ) ) )',
#   '( ( Interest rates ) ( ( should ( increase ( to ( increase saving ) ) ) ) . ) )',
#   '(ROOT (S (ADVP (RB Conversely)) (, ,) (NP (NP (DT an) (NN increase)) (PP (IN in) (NP (NN government) (NN saving)))) (VP (VP (VBZ adds) (PP (TO to) (NP (NP (DT the) (NN supply)) (PP (IN of) (NP (NP (NNS resources)) (ADJP (JJ available) (PP (IN for) (NP (NN investment))))))))) (CC and) (VP (MD may) (VP (VB put) (NP (JJ downward) (NN pressure)) (PP (IN on) (NP (NN interest) (NNS rates)))))) (. .)))',
#   '(ROOT (S (NP (NN Interest) (NNS rates)) (VP (MD should) (VP (VB increase) (S (VP (TO to) (VP (VB increase) (NP (NN saving))))))) (. .)))',
#   'Conversely, an increase in government saving adds to the supply of resources available for investment and may put downward pressure on interest rates.',
#   'Interest rates should increase to increase saving.',
#   '56101',
#   '56101n',
#   'government',
#   'neutral',
#   'contradiction',
#   'contradiction',
#   'contradiction',
#   'contradiction'],
#  ['entailment',
#   "( ( ( ( ( ( Britain 's ) ( best-selling tabloid ) ) , ) ( the Sun ) ) , ) ( ( ( ( announced ( as ( a ( front-page world ) ) ) ) ( exclusive Friday ) ) ( that ( ( Texan ( model ( Jerry Hall ) ) ) ( has ( ( started ( ( divorce proceedings ) ( against ( aging ( rock ( star ( Mick Jagger ) ) ) ) ) ) ) ( at ( ( the ( High Court ) ) ( in London ) ) ) ) ) ) ) ) . ) )",
#   '( There ( ( is ( ( a ( British publication ) ) ( called ( the Sun ) ) ) ) . ) )',
#   "(ROOT (S (NP (NP (NP (NNP Britain) (POS 's)) (JJ best-selling) (NN tabloid)) (, ,) (NP (DT the) (NNP Sun)) (, ,)) (VP (VBD announced) (PP (IN as) (NP (DT a) (JJ front-page) (NN world))) (NP (JJ exclusive) (NNP Friday)) (SBAR (IN that) (S (NP (NNP Texan) (NN model) (NNP Jerry) (NNP Hall)) (VP (VBZ has) (VP (VBN started) (NP (NP (NN divorce) (NNS proceedings)) (PP (IN against) (NP (VBG aging) (NN rock) (NN star) (NNP Mick) (NNP Jagger)))) (PP (IN at) (NP (NP (DT the) (NNP High) (NNP Court)) (PP (IN in) (NP (NNP London)))))))))) (. .)))",
#   '(ROOT (S (NP (EX There)) (VP (VBZ is) (NP (NP (DT a) (JJ British) (NN publication)) (VP (VBN called) (NP (DT the) (NNP Sun))))) (. .)))',
#   "Britain's best-selling tabloid, the Sun , announced as a front-page world exclusive Friday that Texan model Jerry Hall has started divorce proceedings against aging rock star Mick Jagger at the High Court in London.",
#   'There is a British publication called the Sun.',
#   '78648',
#   '78648e',
#   'slate',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment'],
#  ['entailment',
#   '( He ( ( was ( of ( ( ( two minds ) , ) ( one ( reveled ( in ( ( the peace ) ( of ( this village ) ) ) ) ) ) ) ) ) . ) )',
#   '( He ( ( loved ( how ( ( peaceful ( the village ) ) was ) ) ) . ) )',
#   '(ROOT (S (NP (PRP He)) (VP (VBD was) (PP (IN of) (NP (NP (CD two) (NNS minds)) (, ,) (NP (NP (CD one)) (VP (VBN reveled) (PP (IN in) (NP (NP (DT the) (NN peace)) (PP (IN of) (NP (DT this) (NN village)))))))))) (. .)))',
#   '(ROOT (S (NP (PRP He)) (VP (VBD loved) (SBAR (WHADVP (WRB how)) (S (NP (JJ peaceful) (DT the) (NN village)) (VP (VBD was))))) (. .)))',
#   'He was of two minds, one reveled in the peace of this village.',
#   'He loved how peaceful the village was.',
#   '133241',
#   '133241e',
#   'fiction',
#   'entailment',
#   'entailment',
#   'entailment',
#   'neutral',
#   'entailment'],
#  ['neutral',
#   '( ( The vineyards ) ( ( ( ( ( ( ( hug ( ( the ( gentle slopes ) ) ( between ( ( ( the Vosges ) and ) ( the ( Rhine Valley ) ) ) ) ) ) ( along ( ( ( ( ( a ( single ( ( narrow 120-km ) ( ( -LRB- ( 75-mile -RRB- ) ) strip ) ) ) ) ( that ( stretches ( from Marlenheim ) ) ) ) , ) just ) ( west ( of Strasbourg ) ) ) ) ) , ) ( down ( to Thann ) ) ) , ) ( outside Mulhouse ) ) . ) )',
#   '( ( ( The slopes ) ( between ( the ( Vosges ( and ( Rhine Valley ) ) ) ) ) ) ( ( are ( ( the ( only place ) ) ( appropriate ( for vineyards ) ) ) ) . ) )',
#   '(ROOT (S (NP (DT The) (NNS vineyards)) (VP (VBD hug) (NP (NP (DT the) (JJ gentle) (NNS slopes)) (PP (IN between) (NP (NP (DT the) (NNPS Vosges)) (CC and) (NP (DT the) (NNP Rhine) (NNP Valley))))) (PP (IN along) (NP (NP (NP (DT a) (JJ single) (ADJP (JJ narrow) (JJ 120-km)) (PRN (-LRB- -LRB-) (ADJP (JJ 75-mile)) (-RRB- -RRB-)) (NN strip)) (SBAR (WHNP (WDT that)) (S (VP (VBZ stretches) (PP (IN from) (NP (NNP Marlenheim))))))) (, ,) (RB just) (NP (NP (NN west)) (PP (IN of) (NP (NNP Strasbourg)))))) (, ,) (ADVP (RB down) (PP (TO to) (NP (NNP Thann)))) (, ,) (PP (IN outside) (NP (NNP Mulhouse)))) (. .)))',
#   '(ROOT (S (NP (NP (DT The) (NNS slopes)) (PP (IN between) (NP (DT the) (NNPS Vosges) (CC and) (NNP Rhine) (NNP Valley)))) (VP (VBP are) (NP (NP (DT the) (JJ only) (NN place)) (ADJP (JJ appropriate) (PP (IN for) (NP (NNS vineyards)))))) (. .)))',
#   'The vineyards hug the gentle slopes between the Vosges and the Rhine Valley along a single narrow 120-km (75-mile) strip that stretches from Marlenheim, just west of Strasbourg, down to Thann, outside Mulhouse.',
#   'The slopes between the Vosges and Rhine Valley are the only place appropriate for vineyards.',
#   '111643',
#   '111643n',
#   'travel',
#   'neutral',
#   'neutral',
#   'contradiction',
#   'neutral',
#   'neutral'],
#  ['neutral',
#   '( ( ( ( ( We ( ( did not ) ( ( study ( ( the reasons ) ( for ( these deviations ) ) ) ) specifically ) ) ) , ) but ) ( they ( likely ( result ( from ( ( the context ) ( ( in which ) ( ( federal CIOs ) operate ) ) ) ) ) ) ) ) . )',
#   '( ( These deviations ) ( mostly ( ( ( involve failure ) ( to ( ( apply ( software updates ) ) ( in ( a ( timely manner ) ) ) ) ) ) . ) ) )',
#   '(ROOT (S (S (NP (PRP We)) (VP (VBD did) (RB not) (VP (VB study) (NP (NP (DT the) (NNS reasons)) (PP (IN for) (NP (DT these) (NNS deviations)))) (ADVP (RB specifically))))) (, ,) (CC but) (S (NP (PRP they)) (ADVP (RB likely)) (VP (VBP result) (PP (IN from) (NP (NP (DT the) (NN context)) (SBAR (WHPP (IN in) (WHNP (WDT which))) (S (NP (JJ federal) (NNS CIOs)) (VP (VBP operate)))))))) (. .)))',
#   '(ROOT (S (NP (DT These) (NNS deviations)) (ADVP (RB mostly)) (VP (VBP involve) (NP (NN failure)) (S (VP (TO to) (VP (VB apply) (NP (NN software) (NNS updates)) (PP (IN in) (NP (DT a) (JJ timely) (NN manner))))))) (. .)))',
#   'We did not study the reasons for these deviations specifically, but they likely result from the context in which federal CIOs operate.',
#   'These deviations mostly involve failure to apply software updates in a timely manner.',
#   '34776',
#   '34776n',
#   'government',
#   'neutral',
#   'contradiction',
#   'neutral',
#   'neutral',
#   'neutral'],
#  ['entailment',
#   "( Rouen ( ( is ( ( the ( ancient center ) ) ( of ( ( ( ( ( Normandy 's ) ( thriving ( textile industry ) ) ) , ) and ) ( ( the place ) ( of ( Joan ( of ( ( ( ( Arc 's ) ( martyrdom ' ) ) ( a ( national symbol ) ) ) ( of ( resistance ( to tyranny ) ) ) ) ) ) ) ) ) ) ) ) . ) )",
#   '( ( Joan ( of Arc ) ) ( ( ( sacrificed ( her life ) ) ( at ( ( Rouen , ) ( which ( became ( ( an ( enduring symbol ) ) ( of ( opposition ( to tyranny ) ) ) ) ) ) ) ) ) . ) )',
#   "(ROOT (S (NP (NNP Rouen)) (VP (VBZ is) (NP (NP (DT the) (JJ ancient) (NN center)) (PP (IN of) (NP (NP (NP (NNP Normandy) (POS 's)) (JJ thriving) (NN textile) (NN industry)) (, ,) (CC and) (NP (NP (DT the) (NN place)) (PP (IN of) (NP (NP (NNP Joan)) (PP (IN of) (NP (NP (NP (NNP Arc) (POS 's)) (NN martyrdom) (POS ')) (NP (DT a) (JJ national) (NN symbol)) (PP (IN of) (NP (NP (NN resistance)) (PP (TO to) (NP (NN tyranny)))))))))))))) (. .)))",
# ...
#   '38156',
#   '38156c',
#   'government',
#   'contradiction',
#   'neutral',
#   'contradiction',
#   'entailment',
#   'entailment'],
#  ['contradiction',
#   "( ( If ( she ( was n't ) ) ) ( , ( how ( ( ( would they ) ( have ( known ( ( Jane Finn ) ( had ( got ( the papers ) ) ) ) ) ) ) ? ) ) ) )",
#   '( How ( ( ( would they ) ( know ( that ( ( Jane Finn ) ( had ( lost ( the papers ) ) ) ) ) ) ) ? ) )',
#   "(ROOT (SBARQ (SBAR (IN If) (S (NP (PRP she)) (VP (VBD was) (RB n't)))) (, ,) (WHADVP (WRB how)) (SQ (MD would) (NP (PRP they)) (VP (VB have) (VP (VBN known) (SBAR (S (NP (NNP Jane) (NNP Finn)) (VP (VBD had) (VP (VBN got) (NP (DT the) (NNS papers))))))))) (. ?)))",
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (MD would) (NP (PRP they)) (VP (VB know) (SBAR (IN that) (S (NP (NNP Jane) (NNP Finn)) (VP (VBD had) (VP (VBN lost) (NP (DT the) (NNS papers)))))))) (. ?)))',
#   "If she wasn't, how would they have known Jane Finn had got the papers?",
#   'How would they know that Jane Finn had lost the papers?',
#   '130129',
#   '130129c',
#   'fiction',
#   'contradiction',
#   'contradiction',
#   'neutral',
#   'contradiction',
#   'contradiction'],
#  ['neutral',
#   '( ( yeah well ) ( ( at least ) ( as ( they ( told ( us ( uh ( two shifts ) ) ) ) ) ) ) )',
#   '( They ( ( mentioned ( ( at least ) ( ( ( ( ( two shifts ) , ) ( one ( at night ) ) ) , ) ( ( the other ) ( at 6am ) ) ) ) ) . ) )',
#   '(ROOT (S (VP (VB yeah) (ADVP (RB well)) (SBAR (ADVP (IN at) (JJS least)) (IN as) (S (NP (PRP they)) (VP (VBD told) (SBAR (S (NP (PRP us)) (VP (VBZ uh) (NP (CD two) (NNS shifts)))))))))))',
#   '(ROOT (S (NP (PRP They)) (VP (VBD mentioned) (NP (ADVP (IN at) (JJS least)) (NP (CD two) (NNS shifts)) (, ,) (NP (NP (CD one)) (PP (IN at) (NP (NN night)))) (, ,) (NP (NP (DT the) (JJ other)) (PP (IN at) (NP (CD 6am)))))) (. .)))',
#   'yeah well at least as they told us uh two shifts',
#   'They mentioned at least two shifts, one at night, the other at 6am.',
#   '93570',
#   '93570n',
#   'telephone',
#   'neutral',
#   'neutral',
#   'neutral',
#   'neutral',
#   'neutral'],
#  ['neutral',
#   '( well ( what ( ( station plays ) ( uh ( ( that type ) ( of music ) ) ) ) ) )',
#   '( ( ( Which radio ) station ) ( ( plays ( ( a lot ) ( of ( contemporary ( Christian music ) ) ) ) ) ? ) )',
#   '(ROOT (FRAG (ADVP (RB well)) (SBAR (WHNP (WP what)) (S (NP (NN station) (NNS plays)) (VP (VBZ uh) (NP (NP (DT that) (NN type)) (PP (IN of) (NP (NN music)))))))))',
#   '(ROOT (SBARQ (WHNP (WDT Which) (NN radio) (NN station)) (SQ (VP (VBZ plays) (NP (NP (DT a) (NN lot)) (PP (IN of) (NP (JJ contemporary) (JJ Christian) (NN music)))))) (. ?)))',
#   'well what station plays uh that type of music',
#   'Which radio station plays a lot of contemporary Christian music?',
#   '31775',
#   '31775n',
#   'telephone',
#   'neutral',
#   'neutral',
#   'neutral',
#   'entailment',
#   'neutral'],
#  ['contradiction',
#   '( ( In Japan ) ( , ( ( Mainichi Shimbun ) ( ( ( criticized ( the ( new ( Liberal ( Democratic ( Party ( leader ( Keizo Obuchi ) ) ) ) ) ) ) ) ( for ( ( being ( devoid ( of ( fresh ideas ) ) ) ) ( for ( reviving ( the ( Japanese economy ) ) ) ) ) ) ) . ) ) ) )',
#   "( ( Mainichi Shimbun ) ( ( ( approved ( of ( ( Keizo ( Obuchi 's ) ) efforts ) ) ) ( toward ( improving ( the economy ) ) ) ) . ) )",
#   '(ROOT (S (PP (IN In) (NP (NNP Japan))) (, ,) (NP (NNP Mainichi) (NNP Shimbun)) (VP (VBD criticized) (NP (DT the) (JJ new) (NNP Liberal) (NNP Democratic) (NNP Party) (NN leader) (NNP Keizo) (NNP Obuchi)) (PP (IN for) (S (VP (VBG being) (ADJP (JJ devoid) (PP (IN of) (NP (JJ fresh) (NNS ideas)))) (PP (IN for) (S (VP (VBG reviving) (NP (DT the) (JJ Japanese) (NN economy))))))))) (. .)))',
#   "(ROOT (S (NP (NNP Mainichi) (NNP Shimbun)) (VP (VBD approved) (PP (IN of) (NP (NP (NNP Keizo) (NNP Obuchi) (POS 's)) (NNS efforts))) (PP (IN toward) (S (VP (VBG improving) (NP (DT the) (NN economy)))))) (. .)))",
#   'In Japan, Mainichi Shimbun criticized the new Liberal Democratic Party leader Keizo Obuchi for being devoid of fresh ideas for reviving the Japanese economy.',
#   "Mainichi Shimbun approved of Keizo Obuchi's efforts toward improving the economy.",
#   '23410',
#   '23410c',
#   'slate',
#   'contradiction',
#   'contradiction',
#   'contradiction',
#   'contradiction',
#   'contradiction'],
#  ['neutral',
#   '( ( ( ( go up ) ( to ( ( ( ( state parks ) ( with ( six shelters ) ) ) and ) ( ( little screened ) ( in areas ) ) ) ) ) and ) ( then ( ( ( ( travel trailers ) and ) ( ( ( all ( the way ) ) ( up ( to ( conference ( center ( type campings ) ) ) ) ) ) ( that ( have ( uh you ) ) ) ) ) ( ( know ( air conditioning ) ) ( like ( hotels ( with uh ) ) ) ) ) ) )',
#   '( ( The ( state parks ) ) ( ( ( are almost ) ( always ( kept ( in ( good condition ) ) ) ) ) . ) )',
#   '(ROOT (S (VP (VP (VB go) (PRT (RP up)) (PP (TO to) (NP (NP (NP (NN state) (NNS parks)) (PP (IN with) (NP (CD six) (NNS shelters)))) (CC and) (NP (NP (JJ little) (NNS screened)) (PP (IN in) (NP (NNS areas))))))) (CC and) (VP (RB then) (VP (VB travel) (NP (NNS trailers))) (CC and) (ADVP (ADVP (NP (PDT all) (DT the) (NN way)) (RB up) (PP (TO to) (NP (NN conference) (NN center) (NN type) (NNS campings)))) (SBAR (WHNP (WDT that)) (S (VP (VBP have) (VP (VBN uh) (NP (PRP you))))))) (VP (VB know) (NP (NN air) (NN conditioning)) (PP (IN like) (NP (NP (NNS hotels)) (PP (IN with) (NP (INTJ (UH uh)))))))))))',
#   '(ROOT (S (NP (DT The) (NN state) (NNS parks)) (VP (VBP are) (ADVP (RB almost)) (VP (ADVP (RB always)) (VBN kept) (PP (IN in) (NP (JJ good) (NN condition))))) (. .)))',
#   'go up to state parks with six shelters and little screened in areas and then travel trailers and all the way up to conference center type campings that have uh you know air conditioning like hotels with uh',
#   'The state parks are almost always kept in good condition.',
#   '74304',
#   '74304n',
#   'telephone',
#   'neutral',
#   'neutral',
#   'neutral',
#   'neutral',
#   'entailment'],
#  ['contradiction',
#   '( However ( , ( ( ( SCR installations ) ( designed ( to ( comply ( with ( the ( NOX ( SIP Call ) ) ) ) ) ) ) ) ( ( ( ( are generally ) already ) ( ( ( ( into ( the ( installation process ) ) ) or ) ( , ( ( at ( a minimum ) ) , ) ) ) ( into ( ( the ( engineering phase ) ) ( of ( the project ) ) ) ) ) ) . ) ) ) )',
#   "( ( SCR installs ) ( ( ( do n't ) ( have ( ( NOX SIP ) ( to ( comply with ) ) ) ) ) . ) )",
#   '(ROOT (S (ADVP (RB However)) (, ,) (NP (NP (NNP SCR) (NNS installations)) (VP (VBN designed) (S (VP (TO to) (VP (VB comply) (PP (IN with) (NP (DT the) (NNP NOX) (NNP SIP) (NNP Call)))))))) (VP (VBP are) (ADVP (RB generally)) (ADVP (RB already)) (PP (PP (IN into) (NP (DT the) (NN installation) (NN process))) (CC or) (PRN (, ,) (PP (IN at) (NP (DT a) (NN minimum))) (, ,)) (PP (IN into) (NP (NP (DT the) (NN engineering) (NN phase)) (PP (IN of) (NP (DT the) (NN project))))))) (. .)))',
#   "(ROOT (S (NP (NNP SCR) (NNS installs)) (VP (VBP do) (RB n't) (VP (VB have) (S (NP (NNP NOX) (NNP SIP)) (VP (TO to) (VP (VB comply) (PP (IN with))))))) (. .)))",
#   'However, SCR installations designed to comply with the NOX SIP Call are generally already into the installation process or, at a minimum, into the engineering phase of the project.',
#   "SCR installs don't have NOX SIP to comply with.",
#   '108452',
#   '108452c',
#   'government',
#   'contradiction',
#   'contradiction',
#   'contradiction',
#   'contradiction',
#   'contradiction'],
#  ['neutral',
#   '( Also ( , ( ( ( ( ( disappointing earnings ) ( reports ( from Intel ) ) ) and ) ( ( ( other ( blue-chip companies ) ) ( in ( ( the ( two weeks ) ) ( ( leading up ) ( to ( the crash ) ) ) ) ) ) ( ( caused investors ) ( to ( question ( ( the value ) ( of ( entire portfolios ) ) ) ) ) ) ) ) . ) ) )',
#   '( Intel ( ( has ( had ( many ( disappointing ( earning reports ) ) ) ) ) . ) )',
#   '(ROOT (S (ADVP (RB Also)) (, ,) (S (NP (JJ disappointing) (NNS earnings)) (VP (VBZ reports) (PP (IN from) (NP (NNP Intel))))) (CC and) (S (NP (NP (JJ other) (JJ blue-chip) (NNS companies)) (PP (IN in) (NP (NP (DT the) (CD two) (NNS weeks)) (VP (VBG leading) (PRT (RP up)) (PP (TO to) (NP (DT the) (NN crash))))))) (VP (VBD caused) (NP (NNS investors)) (S (VP (TO to) (VP (VB question) (NP (NP (DT the) (NN value)) (PP (IN of) (NP (JJ entire) (NNS portfolios))))))))) (. .)))',
#   '(ROOT (S (NP (NNP Intel)) (VP (VBZ has) (VP (VBN had) (NP (JJ many) (JJ disappointing) (NN earning) (NNS reports)))) (. .)))',
#   'Also, disappointing earnings reports from Intel and other blue-chip companies in the two weeks leading up to the crash caused investors to question the value of entire portfolios.',
#   'Intel has had many disappointing earning reports.',
#   '97066',
#   '97066n',
#   'slate',
#   'neutral',
#   'neutral',
#   'entailment',
#   'neutral',
#   'neutral'],
#  ['-',
#   '( ( Programs ( that ( do this ) ) ) ( typically ( ( have ( successful ( cost ( and ( schedule outcomes ) ) ) ) ) . ) ) )',
#   '( ( Programs ( that ( have ( a ( successful ( ( schedule and ) revenue ) ) ) ) ) ) ( ( do this ) . ) )',
#   '(ROOT (S (NP (NP (NNP Programs)) (SBAR (WHNP (WDT that)) (S (VP (VBP do) (NP (DT this)))))) (ADVP (RB typically)) (VP (VBP have) (NP (JJ successful) (NN cost) (CC and) (NN schedule) (NNS outcomes))) (. .)))',
#   '(ROOT (S (NP (NP (NNP Programs)) (SBAR (WHNP (WDT that)) (S (VP (VBP have) (NP (DT a) (JJ successful) (NN schedule) (CC and) (NN revenue)))))) (VP (VBP do) (NP (DT this))) (. .)))',
#   'Programs that do this typically have successful cost and schedule outcomes.',
#   'Programs that have a successful schedule and revenue do this. ',
#   '20863',
#   '20863e',
#   'government',
#   'entailment',
#   'entailment',
#   'contradiction',
#   'neutral',
#   'neutral'],
#  ['contradiction',
#   "( Well ( , ( we ( ( ( 've just ) ( got ( to ( ( get down ) ( to ( ( it , ) ( that ( 's all ) ) ) ) ) ) ) ) . ) ) ) )",
#   '( We ( ( should ( ( take ( a break ) ) ( from this ) ) ) . ) )',
#   "(ROOT (S (INTJ (UH Well)) (, ,) (NP (PRP we)) (VP (VBP 've) (ADVP (RB just)) (VP (VBN got) (S (VP (TO to) (VP (VB get) (PRT (RP down)) (PP (TO to) (NP (NP (PRP it)) (, ,) (SBAR (WHNP (WDT that)) (S (VP (VBZ 's) (NP (DT all)))))))))))) (. .)))",
#   '(ROOT (S (NP (PRP We)) (VP (MD should) (VP (VB take) (NP (DT a) (NN break)) (PP (IN from) (NP (DT this))))) (. .)))',
#   "Well, we've just got to get down to it, that's all.",
#   'We should take a break from this.',
#   '143768',
#   '143768c',
#   'fiction',
#   'contradiction',
#   'contradiction',
#   'contradiction',
#   'contradiction',
#   'contradiction'],
#  ['contradiction',
#   '( ( , ( ( ( ( ( number ( of ( ( parks or ) acres ) ) ) ( of land ) ) -RRB- ) ( rather ( than ( in terms ) ) ) ) ( of historical ) ) ) ( cost . ) )',
#   '( ( Land ( owned ( by parks ) ) ) ( ( ( does not ) ( have ( a value ) ) ) . ) )',
#   '(ROOT (S (NP (PRN (, ,) (PP (PP (NP (NP (NN number)) (PP (IN of) (NP (NNS parks) (CC or) (NNS acres))) (PP (IN of) (NP (NN land))) (-RRB- -RRB-)) (PP (RB rather) (IN than) (PP (IN in) (NP (NNS terms))))) (PP (IN of) (NP (JJ historical)))))) (VP (VBD cost)) (. .)))',
#   '(ROOT (S (NP (NP (NNP Land)) (VP (VBN owned) (PP (IN by) (NP (NNS parks))))) (VP (VBZ does) (RB not) (VP (VB have) (NP (DT a) (NN value)))) (. .)))',
#   ', number of parks or acres of land) rather than in terms of historical cost.',
#   'Land owned by parks does not have a value.',
#   '116970',
#   '116970c',
#   'government',
#   'contradiction',
#   'contradiction',
#   'neutral',
#   'neutral',
#   'contradiction'],
#  ['neutral',
#   '( ( ( ( Merrion ( Square West ) ) , ) ( Dublin 2 ) ) . )',
#   '( ( Across ( ( the street ) ( from ( a ( Burger King ) ) ) ) ) . )',
#   '(ROOT (NP (NP (NNP Merrion) (NNP Square) (NNP West)) (, ,) (NP (NNP Dublin) (CD 2)) (. .)))',
#   '(ROOT (FRAG (PP (IN Across) (NP (NP (DT the) (NN street)) (PP (IN from) (NP (DT a) (NNP Burger) (NNP King))))) (. .)))',
#   'Merrion Square West, Dublin 2.',
#   'Across the street from a Burger King.',
#   '68456',
#   '68456n',
#   'travel',
#   'neutral',
#   'neutral',
#   'neutral',
#   'neutral',
#   'contradiction'],
#  ['contradiction',
#   "( ( As ( for ( ( the ( divisive issue ) ) ( of ( whether ( ( the Mass ) ( is ( ( a sacrifice ) ( for ( ( the remission ) ( of sins ) ) ) ) ) ) ) ) ) ) ) ( , ( ( the statement ) ( ( ( affirms ( ( that ( Christ 's ) ) death ) ) ( upon ( the cross ) ) ) ... ) ) ) )",
#   "( ( The statement ) ( ( ( does not ) ( ( say anything ) ( about ( ( ( Christ 's ) death ) ( on ( the cross ) ) ) ) ) ) . ) )",
#   "(ROOT (S (PP (IN As) (IN for) (NP (NP (DT the) (JJ divisive) (NN issue)) (PP (IN of) (SBAR (IN whether) (S (NP (DT the) (NNP Mass)) (VP (VBZ is) (NP (NP (DT a) (NN sacrifice)) (PP (IN for) (NP (NP (DT the) (NN remission)) (PP (IN of) (NP (NNS sins)))))))))))) (, ,) (NP (DT the) (NN statement)) (VP (VBZ affirms) (NP (NP (DT that) (NNP Christ) (POS 's)) (NN death)) (PP (IN upon) (NP (DT the) (NN cross)))) (: ...)))",
#   "(ROOT (S (NP (DT The) (NN statement)) (VP (VBZ does) (RB not) (VP (VB say) (NP (NN anything)) (PP (IN about) (NP (NP (NP (NNP Christ) (POS 's)) (NN death)) (PP (IN on) (NP (DT the) (NN cross))))))) (. .)))",
#   "As for the divisive issue of whether the Mass is a sacrifice for the remission of sins, the statement affirms that Christ's death upon the cross ...",
#   "The statement does not say anything about Christ's death on the cross.",
#   '134827',
#   '134827c',
#   'slate',
#   'contradiction',
#   'contradiction',
#   'contradiction',
#   'contradiction',
#   'contradiction'],
#  ['neutral',
#   "( it ( ( 's neat ) ( when ( you ( think ( about ( ( how ( she ( ( ( wrote it ) and ) ( stuff otherwise ) ) ) ) ( ( the lyrics ) ( are ( kind of ) ) ) ) ) ) ) ) ) )",
#   '( I ( ( think ( she ( ( wrote it ) ( when ( she ( ( was drunk ) ( one night ) ) ) ) ) ) ) . ) )',
#   "(ROOT (S (NP (PRP it)) (VP (VBZ 's) (ADJP (JJ neat)) (SBAR (WHADVP (WRB when)) (S (NP (PRP you)) (VP (VBP think) (SBAR (IN about) (S (SBAR (WHADVP (WRB how)) (S (NP (PRP she)) (VP (VP (VBD wrote) (NP (PRP it))) (CC and) (VP (VBP stuff) (ADVP (RB otherwise)))))) (NP (DT the) (NNS lyrics)) (VP (VBP are) (ADVP (NN kind) (IN of)))))))))))",
#   '(ROOT (S (NP (PRP I)) (VP (VBP think) (SBAR (S (NP (PRP she)) (VP (VBD wrote) (NP (PRP it)) (SBAR (WHADVP (WRB when)) (S (NP (PRP she)) (VP (VBD was) (ADJP (JJ drunk)) (NP (CD one) (NN night))))))))) (. .)))',
#   "it's neat when you think about how she wrote it and stuff otherwise the lyrics are kind of",
#   'I think she wrote it when she was drunk one night. ',
#   '72796',
#   '72796n',
#   'telephone',
#   'neutral',
#   'neutral',
#   'neutral',
#   'neutral',
#   'neutral'],
#  ['entailment',
#   "( ( uh-huh ( uh-huh uh-huh ) ) ( ( yeah well ) ( that ( 's ( really neat ) ) ) ) )",
#   "( That ( ( 's cool ) . ) )",
#   "(ROOT (S (NP (JJ uh-huh) (JJ uh-huh) (NNS uh-huh)) (VP (VBP yeah) (ADVP (RB well)) (SBAR (IN that) (S (VP (VBZ 's) (ADJP (RB really) (JJ neat))))))))",
#   "(ROOT (S (NP (DT That)) (VP (VBZ 's) (ADJP (JJ cool))) (. .)))",
#   "uh-huh uh-huh uh-huh yeah well that's really neat",
#   "That's cool.",
#   '95842',
#   '95842e',
#   'telephone',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment',
#   'entailment'],
#  ['entailment',
#   '( It ( ( ( can not ) ( be outlawed ) ) . ) )',
#   "( It ( ( ( 's not ) ( something ( that ( can ( be ( made illegal ) ) ) ) ) ) . ) )",
#   '(ROOT (S (NP (PRP It)) (VP (MD can) (RB not) (VP (VB be) (VP (VBN outlawed)))) (. .)))',
#   "(ROOT (S (NP (PRP It)) (VP (VBZ 's) (RB not) (NP (NP (NN something)) (SBAR (WHNP (WDT that)) (S (VP (MD can) (VP (VB be) (VP (VBN made) (S (ADJP (JJ illegal)))))))))) (. .)))",
#   'It cannot be outlawed.',
#   "It's not something that can be made illegal.",
#   '16494',
#   '16494e',
#   'slate',
#   'entailment',
#   'entailment',
#   'contradiction',
#   'entailment',
#   'entailment'],
#  ['neutral',
#   '( The ( truth ? ) )',
#   '( ( ( Will you ) ( tell ( the truth ) ) ) ? )',
#   '(ROOT (NP (DT The) (NN truth) (. ?)))',
#   '(ROOT (SQ (MD Will) (NP (PRP you)) (VP (VB tell) (NP (DT the) (NN truth))) (. ?)))',
#   'The truth?',
#   'Will you tell the truth?',
#   '48453',
#   '48453n',
#   'slate',
#   'neutral',
#   'entailment',
#   'neutral',
#   'neutral',
#   'neutral'],
#  ...]

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from transformers import AutoTokenizer
from transformers import BertModel
from datasets import load_dataset

from torch.optim import AdamW
from transformers import get_scheduler
from tqdm.auto import tqdm

from datasets import load_metric

class PlaceHolderBERT(nn.Module):
    def __init__(self, num_out=1, sigmoid=False, return_CLS_representation=False):
        super().__init__()
        #self.tokenizer = AutoTokenizer.from_pretrained('bert-base-cased')
        self.bert = BertModel.from_pretrained('bert-base-cased')
        self.linear = nn.Linear(768,num_out)
        self.return_CLS_representation = return_CLS_representation
        self.sigmoid_bool = sigmoid
        self.sigmoid = nn.Sigmoid()
    def forward(self, x):
        #embeddings = self.tokenizer(x, return_tensors='pt', padding=True)
        #embeddings.to(device)
        representations = self.bert(**x).last_hidden_state
        cls_representation = representations[:,0,:]
        pred = self.linear(cls_representation)
        if self.return_CLS_representation:
            return cls_representation
        if self.sigmoid_bool:
            return self.sigmoid(pred)
        return pred
    
    
def train(model, dataloader, num_epochs=1): #can scrap keyword
    #optimizer as usual
    optimizer = AdamW(model.parameters(), lr=5e-5)
    loss_function = torch.nn.MSELoss()
    #learning rate scheduler
    num_training_steps = num_epochs * len(dataloader)
    lr_scheduler = get_scheduler(name="linear", optimizer=optimizer, num_warmup_steps=0, num_training_steps=num_training_steps)

    device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
    model.to(device)

    #auto logging; progress bar
    progress_bar = tqdm(range(num_training_steps))

    #training loop
    model.train()
    for epoch in range(num_epochs):
        for batch in dataloader: #tryin unpacking text from 'labels' as in model development
            batch = {k: v.to(device) for k, v in batch.items()}
            features = {k: v for k, v in batch.items() if k != 'labels'}
            preds = model(features)
            loss = loss_function(preds, batch['labels'].float()) #replace .loss
            loss.backward()

            optimizer.step()
            lr_scheduler.step()
            optimizer.zero_grad()
            progress_bar.update(1)
            

def evaluate(model, dataloader):
    device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
    model.to(device)
    model.eval()
    num_correct = 0
    num_samples = 0
    for batch in dataloader:
        batch = {k: v.to(device) for k, v in batch.items()}
        features = {k: v for k, v in batch.items() if k != 'labels'}
        with torch.no_grad():
            preds = model(features)
            preds = torch.where(preds < .5, 0, 1)
            labels = batch['labels'].reshape(preds.shape)
            num_correct += (preds==labels).sum()
            num_samples += preds.size(0)
    return float(num_correct)/float(num_samples)*100 




imdb = load_dataset('imdb')
sst2 = load_dataset('glue','sst2')

tokenizer = AutoTokenizer.from_pretrained("bert-base-cased")

#tokenize function
def tokenize_imdb(examples):
    return tokenizer(examples['text'], padding="max_length", truncation=True)

def tokenize_sst2(examples):
    return tokenizer(examples['sentence'], padding="max_length", truncation=True)

#pre-tokenize entire dataset
tokenized_imdb = imdb.map(tokenize_imdb, batched=True)
tokenized_sst2 = sst2.map(tokenize_sst2, batched=True)

tokenized_imdb = tokenized_imdb.remove_columns(["text"])
tokenized_imdb = tokenized_imdb.rename_column("label", "labels")
tokenized_imdb.set_format("torch")

tokenized_sst2 = tokenized_sst2.remove_columns(["sentence","idx"])
tokenized_sst2 = tokenized_sst2.rename_column("label", "labels")
tokenized_sst2.set_format("torch")


### Only for practive
imdb_small_train = tokenized_imdb['train'].shuffle(seed=42).select(range(1000))
imdb_small_test = tokenized_imdb['test'].shuffle(seed=42).select(range(500))
###
imdb_train_loader = DataLoader(imdb_small_train, shuffle=True, batch_size=8)
imdb_test_loader = DataLoader(imdb_small_test, shuffle=True, batch_size=8)

sst2_small_train = tokenized_sst2["train"].shuffle(seed=42).select(range(1000))
sst2_small_test = tokenized_sst2["validation"].shuffle(seed=42).select(range(500)) #actual test set is fucked up

sst2_train_loader = DataLoader(sst2_small_train, shuffle=True, batch_size=8)
sst2_test_loader = DataLoader(sst2_small_test, shuffle=True, batch_size=8)
